# %% [markdown]
# ## Random numbers in python

# %%
import random
import matplotlib.pyplot as plt
import scipy.stats as stats

# %%
x=random.random()
x
# Out:
# 0.741648381811525

# %%
x= random.random() # Generate a random number between 0 and 1
values = [random.random() for i in range(1000)]
# values
plt.plot(values)

# %%
x1=random.uniform(0,10)
values = [random.uniform(0,10) for i in range(1000)]
plt.plot(values)

# %%
x1 = random.expovariate(1) # Generate a random number using exponential distribution
values1 = [ random.expovariate(1) for i in range(1000) ]
plt.plot(values1)

# %%
x2= random.gauss(0,1) # Generate a random number using Gaussian distribution
values2 = [ random.gauss(0,1) for i in range(1000) ]
plt.plot(values2)

# %%
x=random.random() # Generate a random number between 0 and 1
y=random.uniform(1,10) # Generate a random number between 1 and 10
z=random.randint(1,10)  # Generate a random integer between 1 and 10
print(x,y,z)
# Out:
# 0.29371984820701624 1.5771614258831737 4

# %%
coin_toss = [random.randint(0,1) for i in range(1000)]
sum(coin_toss)/len(coin_toss)
# Out:
# 0.475

# %%
# random choice from list
greetings = ['hello', 'hi', 'hey', 'hola', 'bonjour']
random.choice(greetings) # random choice from list
random.choices(greetings, k=7) # random choice from list with k=3
# Out:
# 'hi'
# ['hi', 'bonjour', 'hey', 'hola', 'hey', 'hola', 'hola']

# %%
# weighted random choice from list
colors = ["red", "green", "blue", "yellow", "orange", "purple"]
results = random.choices(colors, weights=[5.2, 0.1, 0.3, 0.2, 0.2, 0.2], k=10)
results
# Out:
# ['red', 'blue', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red']

# %%
# Shuffle a list
deck = list(range(1,53))
random.shuffle(deck)
print(deck)
# Out:
# [20, 52, 46, 19, 50, 1, 8, 11, 26, 38, 48, 49, 24, 35, 14, 27, 51, 42, 21, 10, 2, 40, 37, 47, 25, 44, 3, 23, 41, 43, 9, 13, 30, 7, 33, 5, 28, 32, 17, 4, 31, 29, 6, 39, 34, 15, 16, 22, 45, 36, 18, 12]

# %%
# randome sample from list
sample = random.sample(deck, k=5)
print(sample)
# Out:
# [50, 23, 17, 13, 28]

# %%
# Generating fake data 
first_names = ["Alice", "Bob", "Cathy", "Dan", "Ed", "Frank", "George"]
last_names = ["Smith", "Jones", "Brown", "Davis", "Garcia", "Miller"]

cities = ["New York City", "Los Angeles", "Chicago", "Houston", "Phoenix", "Philadelphia", "San Antonio", "San Diego", "Dallas", "San Jose"]

states = ["New York", "California", "Illinois", "Texas", "Arizona", "Florida", "Pennsylvania", "California", "Illinois", "Texas"]

data = []
for i in range(10):
    first = random.choice(first_names)
    last = random.choice(last_names)
    
    phone = f"{random.randint(100,999)}-{random.randint(100,999)}-{random.randint(1000,9999)}"
    
    street = random.randint(100,999)
    city = random.choice(cities)
    state = random.choice(states)
    zipcode = random.randint(10000, 99999)
    
    address = f"{street} {city} {state} {zipcode}"
    
    email = first.lower() + "." + last.lower() + "@gmail.com"
    print(f"{first} {last} {phone} {address} {email}\n")
    data.append([first, last, phone, address, email])
# Out:
# Cathy Davis 506-984-8435 213 San Antonio California 57207 cathy.davis@gmail.com
#
# Ed Smith 679-493-2605 362 Chicago Florida 20566 ed.smith@gmail.com
#
# Bob Brown 784-200-8605 251 New York City Illinois 80100 bob.brown@gmail.com
#
# Ed Davis 823-746-3483 822 Philadelphia California 52733 ed.davis@gmail.com
#
# Ed Jones 277-323-6370 152 San Diego Florida 96281 ed.jones@gmail.com
#
# Cathy Brown 975-655-7521 240 Chicago Florida 49127 cathy.brown@gmail.com
#
# Alice Jones 911-983-9303 369 Philadelphia Illinois 60670 alice.jones@gmail.com
#
# Frank Smith 751-119-4692 203 Philadelphia New York 66606 frank.smith@gmail.com
#
# Alice Miller 825-812-6131 762 San Jose Illinois 49656 alice.miller@gmail.com
#
# Alice Davis 718-557-4195 735 Phoenix New York 98697 alice.davis@gmail.com

# %%
data
# Out:
# [['Frank',
#   'Garcia',
#   '985-987-4208',
#   '503 Phoenix California 56930',
#   'frank.garcia@gmail.com'],
#  ['Bob',
#   'Miller',
#   '824-173-8404',
#   '392 Phoenix Illinois 92135',
#   'bob.miller@gmail.com'],
#  ['Alice',
#   'Brown',
#   '386-323-7491',
#   '918 Los Angeles California 84561',
#   'alice.brown@gmail.com'],
#  ['George',
#   'Miller',
#   '793-702-6473',
#   '447 New York City Illinois 95961',
#   'george.miller@gmail.com'],
#  ['Dan',
#   'Davis',
#   '944-601-4374',
#   '683 San Diego Illinois 64423',
#   'dan.davis@gmail.com'],
#  ['Cathy',
#   'Miller',
#   '889-724-1771',
#   '274 Philadelphia Florida 16879',
#   'cathy.miller@gmail.com'],
#  ['Dan',
#   'Brown',
#   '681-704-4028',
#   '262 San Antonio New York 91407',
#   'dan.brown@gmail.com'],
#  ['Cathy',
#   'Brown',
#   '673-985-4122',
#   '478 Philadelphia Texas 18473',
#   'cathy.brown@gmail.com'],
#  ['Ed',
#   'Davis',
#   '321-444-4445',
#   '812 Phoenix Florida 92169',
#   'ed.davis@gmail.com'],
#  ['Dan',
#   'Smith',
#   '759-675-2096',
#   '914 Chicago California 17257',
#   'dan.smith@gmail.com']]
